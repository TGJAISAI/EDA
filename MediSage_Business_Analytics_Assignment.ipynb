# %% [markdown]
# <a href="https://colab.research.google.com/github/TGJAISAI/EDA/blob/main/MediSage_Business_Analytics_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/TGJAISAI/training-dataset-/main/Untitled%20spreadsheet.csv")
df.head()
# Out:
#   Company Name Employee Name Item Bought
# 0       Google          Josh          TV
# 1       Google          John          TV
# 2        Apple         Kathy      Mobile
# 3       Google         Karen      Laptop
# 4     Facebook         Peter      Laptop

# %%
df.shape
# Out:
# (23, 3)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df1 = df.groupby('Company Name')['Employee Name'].nunique().sort_values(ascending=False)
pd.DataFrame(df1)
# Out:
#               Employee Name
# Company Name
# Apple                     3
# Google                    3
# Facebook                  2
# Netflix                   2

# %%
df2 = df.groupby('Company Name')['Employee Name'].unique()
pd.DataFrame(df2)
# Out:
#                       Employee Name
# Company Name
# Apple         [Kathy, George, Matt]
# Facebook             [Peter, Stacy]
# Google          [Josh, John, Karen]
# Netflix               [Rita, Keith]

# %%
a.shape
# Out:
# (4,)

# %%
df3 = df.groupby('Company Name')['Item Bought'].nunique().sort_values(ascending=False)
pd.DataFrame(df3)
# Out:
#               Item Bought
# Company Name
# Facebook                4
# Apple                   3
# Netflix                 3
# Google                  2

# %% [markdown]
# **the final ans:**

# %%
result = pd.concat([df1,df2, df3], axis=1)
result
# Out:
#              Employee Name          Employee Name  Item Bought
# Company Name
# Apple                    3  [Kathy, George, Matt]            3
# Google                   3    [Josh, John, Karen]            2
# Facebook                 2         [Peter, Stacy]            4
# Netflix                  2          [Rita, Keith]            3

# %% [markdown]
# **2**
# ![image.png](data:image/png;base64,...)

# %%
tabel1 = df.groupby(["Company Name","Employee Name"])["Item Bought"].value_counts()
pd.DataFrame(tabel1)
# Out:
#                                         Item Bought
# Company Name Employee Name Item Bought
# Apple        George        Mobile                 1
#              Kathy         Headphone              1
#                            Mobile                 1
#              Matt          Laptop                 1
#                            Mobile                 1
# Facebook     Peter         Laptop                 2
#                            Headphone              1
#              Stacy         Headphone              1
#                            Mobile                 1
#                            TV                     1
# Google       John          TV                     2
#              Josh          TV                     1
#              Karen         Laptop                 2
#                            TV                     1
# Netflix      Keith         Headphone              2
#              Rita          TV                     2
# ...

# %%
df=pd.read_csv("https://raw.githubusercontent.com/TGJAISAI/training-dataset-/main/purchase_dataset.csv")
df.head()
# Out:
#          date  customer_id  product_category payment_method  value [USD]  \
# 0  20/11/2018        37077               505         credit        49.53
# 1  20/11/2018        59173               509         paypal        50.61
# 2  20/11/2018        41066               507         credit        85.99
# 3  20/11/2018        50741               506         credit        34.60
# 4  20/11/2018        53639               515         paypal       266.27
#
#    time_on_site [Minutes]  clicks_in_site campaign_number
# 0                    12.0               8      Campaign 1
# 1                    25.9               8      Campaign 1
# 2                    34.9              11      Campaign 1
# 3                    16.5               9      Campaign 1
# 4                    43.1              30      Campaign 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.shape
# Out:
# (24999, 8)

# %%
df.isnull().sum()
# Out:
# date                      0
# customer_id               0
# product_category          0
# payment_method            0
# value [USD]               0
# time_on_site [Minutes]    0
# clicks_in_site            0
# campaign_number           0
# dtype: int64

# %%
newdf=df["payment_method"].value_counts()
newdf
# Out:
# credit    14459
# paypal    10540
# Name: payment_method, dtype: int64

# %%
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")
plt.figure(figsize=(20,8))
sns.set_palette("crest", 5)
ax = sns.countplot(x="payment_method", data=df)

# %% [markdown]
# **observation**
#
#          *Out of customer 24999, 14459 customer are using credit
#          *paypal has 10540 customer
#          *paypal has to be promoted more
#          *moreover have only two payment mode is not good idea
#          *The market has more DIGITAL PAYMENT METHODS like UPI and more

# %%
fig = plt.figure(figsize = (15, 10))
df.groupby('customer_id')['value [USD]'].sum().sort_values(ascending=False).head(10).plot.bar()

# %% [markdown]
# **observation**
#
#            *The customer_id 51660 has highest number of payment
#            *The bar plot show us top 10 payment value in USD

# %%
newdf=df["campaign_number"].value_counts()
newdf
# Out:
# Campaign 2    9853
# Campaign 3    6549
# Campaign 1    4327
# Campaign 4    4270
# Name: campaign_number, dtype: int64

# %%
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")
plt.pie(df['campaign_number'].value_counts(),radius=3,labels=["Campaign 2","Campaign 3","Campaign 1","Campaign 4"])
plt.show()

# %% [markdown]
# **observation**
#
#           *Campaign 2 are highly active withus
#           *campaign 3 are also active but
#           *campaign 2&1 have to concentrated more

# %%
plt.figure(figsize=(20,8))
sns.barplot(df['campaign_number'],df['value [USD]'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **observation**
#
#          *Campaign 2 are best customer of all
#          *Campaign 1&3&4 has to been given more attention and offers to make them purchase

# %%
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")
plt.figure(figsize=(20,8))
g=sns.scatterplot(x=df['time_on_site [Minutes]'].sort_values(),y=df['clicks_in_site'],hue=df["campaign_number"])

# %%
newdf=df["product_category"].value_counts()
newdf
# Out:
# 505    2103
# 503    1713
# 510    1680
# 508    1675
# 504    1647
# 507    1639
# 502    1630
# 514    1625
# 506    1624
# 511    1623
# 512    1618
# 515    1611
# 501    1606
# 509    1603
# 513    1602
# Name: product_category, dtype: int64

# %%
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")
plt.figure(figsize=(20,8))
sns.set_palette("crest", 5)
ax = sns.countplot(x="product_category", data=df)

# %% [markdown]
# **observation**
#
#                *505 is the best product category off all
#                * rest of them need to marketed more
#                * understand the target group based on that we have to make the marketing

# %% [markdown]
# **THE END!**
#
#  I really want to thank you for give me chance, looking forward to learn more from you
